# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # This files demonstrates how to extract and plot data from the data files

# %%
# Read data into a dataframe
classroom1_data = pd.read_parquet('../Classroom1_clean.parquet', engine='pyarrow')
classroom1_data.head()
# Out:
#                      CO₂ Concentration (ppm)  Occupanty (#)  \
# Timestamp
# 2022-04-05 00:00:00                    421.0            0.0
# 2022-04-05 00:01:00                    420.0            0.0
# 2022-04-05 00:02:00                    419.0            0.0
# 2022-04-05 00:03:00                    421.0            0.0
# 2022-04-05 00:04:00                    421.0            0.0
#
#                      Supply Air Flow (cfm)  Room Relative Humidity (%)  \
# Timestamp
# 2022-04-05 00:00:00                  810.0                       18.20
# 2022-04-05 00:01:00                  810.0                       18.13
# 2022-04-05 00:02:00                  810.0                       18.14
# 2022-04-05 00:03:00                  810.0                       18.12
# 2022-04-05 00:04:00                  810.0                       18.11
#
#                      Room Temperature (%)
# Timestamp
# 2022-04-05 00:00:00                68.936
# 2022-04-05 00:01:00                68.954
# ...

# %%
# Plot CO2 concentration
plt.plot(classroom1_data["CO₂ Concentration (ppm)"])
